# %%
import pandas as pd

# %%
#pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Provisional COVID-19 Deaths by Sex and Age

# %%
provisional_df = pd.read_csv('datasets/Provisional_COVID-19_Deaths_by_Sex_and_Age.csv')
provisional_df
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 1       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 2       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 3       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# 4       09/27/2023  01/01/2020  09/23/2023  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 137695  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137696  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137697  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137698  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
# 137699  09/27/2023  09/01/2023  09/23/2023  By Month  2023.0    9.0
#
#                 State        Sex          Age Group  COVID-19 Deaths  \
# 0       United States  All Sexes           All Ages        1146774.0
# ...

# %% [markdown]
# # NST-EST2024

# %%
nst_df = pd.read_csv('datasets/')
nst_df
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0   Annual Estimates of the Resident Population fo...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                       United States
# 4                                           Northeast
# ..                                                ...
# 62  Note: The estimates are developed from a base ...
# 63                                Suggested Citation:
# 64  Annual Estimates of the Resident Population fo...
# 65    Source: U.S. Census Bureau, Population Division
# 66                        Release Date: December 2024
#
#                       Unnamed: 1                          Unnamed: 2  \
# 0                            NaN                                 NaN
# 1   April 1, 2020 Estimates Base  Population Estimate (as of July 1)
# ...

# %% [markdown]
# # USA States to region

# %% [markdown]
# ### States

# %%
state = pd.read_csv('datasets/region.csv')
# Out:
#            state  estimate base       2020         2021         2022  \
# 0  United States      331515736  331577720  332099760.0  334017321.0
# 1      Northeast       57617706   57431458   57252533.0   57159597.0
# 2        Midwest       68998970   68984258   68872831.0   68903297.0
# 3          South      126281537  126476549  127368010.0  129037849.0
# 4           West       78617523   78685455   78606386.0   78916578.0
#
#           2023         2024
# 0  336806231.0  340110988.0
# 1   57398303.0   57832935.0
# 2   69186401.0   69596584.0
# 3  130893358.0  132665693.0
# 4   79328169.0   80015776.0
