# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Preprocess

# %%
df = pd.read_csv('datasets/covid_2020_2022.csv')
area = pd.read_csv('datasets/us-state-land-area.csv')
df
# Out:
#        Start Date    End Date     Group  Year  Month    State        Sex  \
# 0      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 1      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 2      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 3      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 4      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# ...           ...         ...       ...   ...    ...      ...        ...
# 73435  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73436  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73437  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73438  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73439  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
#
#                Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0               All Ages          21520.0      231602.0           17619.0
# 1           Under 1 year              NaN        1491.0              19.0
# 2              1-4 years              NaN         344.0              13.0
# 3             5-14 years              NaN         453.0              11.0
# 4            15-24 years             46.0        2672.0              51.0
# ...                  ...              ...           ...               ...
# 73435        45-54 years              0.0          11.0               NaN
# 73436        55-64 years              NaN          25.0               NaN
# 73437        65-74 years              NaN          35.0               NaN
# 73438        75-84 years              NaN          48.0               NaN
# 73439  85 years and over              NaN          83.0               NaN
#
#        Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0                             7411.0             356.0
# 1                                NaN               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                               16.0               NaN
# ...                              ...               ...
# 73435                            0.0               0.0
# 73436                            NaN               0.0
# 73437                            NaN               NaN
# 73438                            NaN               NaN
# 73439                            0.0               0.0
#
#        Pneumonia, Influenza, or COVID-19 Deaths State Code Region  \
# 0                                       32038.0         AL  South
# 1                                          24.0         AL  South
# 2                                          19.0         AL  South
# 3                                          16.0         AL  South
# 4                                          85.0         AL  South
# ...                                         ...        ...    ...
# 73435                                       NaN         WY   West
# 73436                                       NaN         WY   West
# 73437                                       NaN         WY   West
# 73438                                       NaN         WY   West
# 73439                                       NaN         WY   West
#
#        estimate base  Population
# 0            5025369         NaN
# 1            5025369         NaN
# 2            5025369         NaN
# 3            5025369         NaN
# 4            5025369         NaN
# ...              ...         ...
# 73435         576844    581978.0
# 73436         576844    581978.0
# 73437         576844    581978.0
# 73438         576844    581978.0
# 73439         576844    581978.0
#
# [73440 rows x 18 columns]

# %%
df.rename(columns={'State': 'state'}, inplace=True)
area = area.loc[:, ['state', 'land_area_sq_mi']].rename(columns={'land_area_sq_mi': 'land_area'}).iloc[0:51]
area
# Out:
#                    state  land_area
# 0                 Alaska  570640.95
# 1                  Texas  261231.71
# 2             California  155779.22
# 3                Montana  145545.80
# 4             New Mexico  121298.15
# 5                Arizona  113594.08
# 6                 Nevada  109781.18
# 7               Colorado  103641.89
# 8                 Oregon   95988.01
# 9                Wyoming   97093.14
# 10              Michigan   56538.90
# 11             Minnesota   79626.74
# 12                  Utah   82169.62
# 13                 Idaho   82643.12
# 14                Kansas   81758.72
# 15              Nebraska   76824.17
# 16          South Dakota   75811.00
# 17            Washington   66455.52
# 18          North Dakota   69000.80
# 19              Oklahoma   68594.92
# 20              Missouri   68741.52
# 21               Florida   53624.76
# 22             Wisconsin   54157.80
# 23               Georgia   57513.49
# 24              Illinois   55518.93
# 25                  Iowa   55857.13
# 26              New York   47126.40
# 27        North Carolina   48617.91
# 28              Arkansas   52035.48
# 29               Alabama   50645.33
# 30             Louisiana   43203.90
# 31           Mississippi   46923.27
# 32          Pennsylvania   44742.70
# 33                  Ohio   40860.69
# 34              Virginia   39490.09
# 35             Tennessee   41234.90
# 36              Kentucky   39486.34
# 37               Indiana   35826.11
# 38                 Maine   30842.92
# 39        South Carolina   30060.70
# 40         West Virginia   24038.21
# 41              Maryland    9707.24
# 42                Hawaii    6422.63
# 43         Massachusetts    7800.06
# 44               Vermont    9216.66
# 45         New Hampshire    8952.65
# 46            New Jersey    7354.22
# 47           Connecticut    4842.36
# 48              Delaware    1948.54
# 49          Rhode Island    1033.81
# 50  District of Columbia      61.05

# %%
df = pd.merge(df, area,on='state', how='left')
df
# Out:
#        Start Date    End Date     Group  Year  Month    state        Sex  \
# 0      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 1      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 2      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 3      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 4      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# ...           ...         ...       ...   ...    ...      ...        ...
# 73435  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73436  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73437  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73438  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73439  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
#
#                Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0               All Ages          21520.0      231602.0           17619.0
# 1           Under 1 year              NaN        1491.0              19.0
# 2              1-4 years              NaN         344.0              13.0
# 3             5-14 years              NaN         453.0              11.0
# 4            15-24 years             46.0        2672.0              51.0
# ...                  ...              ...           ...               ...
# 73435        45-54 years              0.0          11.0               NaN
# 73436        55-64 years              NaN          25.0               NaN
# 73437        65-74 years              NaN          35.0               NaN
# 73438        75-84 years              NaN          48.0               NaN
# 73439  85 years and over              NaN          83.0               NaN
#
#        Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0                             7411.0             356.0
# 1                                NaN               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                               16.0               NaN
# ...                              ...               ...
# 73435                            0.0               0.0
# 73436                            NaN               0.0
# 73437                            NaN               NaN
# 73438                            NaN               NaN
# 73439                            0.0               0.0
#
#        Pneumonia, Influenza, or COVID-19 Deaths State Code Region  \
# 0                                       32038.0         AL  South
# 1                                          24.0         AL  South
# 2                                          19.0         AL  South
# 3                                          16.0         AL  South
# 4                                          85.0         AL  South
# ...                                         ...        ...    ...
# 73435                                       NaN         WY   West
# 73436                                       NaN         WY   West
# 73437                                       NaN         WY   West
# 73438                                       NaN         WY   West
# 73439                                       NaN         WY   West
#
#        estimate base  Population  land_area
# 0            5025369         NaN   50645.33
# 1            5025369         NaN   50645.33
# 2            5025369         NaN   50645.33
# 3            5025369         NaN   50645.33
# 4            5025369         NaN   50645.33
# ...              ...         ...        ...
# 73435         576844    581978.0   97093.14
# 73436         576844    581978.0   97093.14
# 73437         576844    581978.0   97093.14
# 73438         576844    581978.0   97093.14
# 73439         576844    581978.0   97093.14
#
# [73440 rows x 19 columns]

# %%
df['density'] = df['Population'] / df['land_area']
df['death_density'] = df['Total Deaths'] / df['land_area']
df['covid_density'] = df['COVID-19 Deaths'] / df['land_area']
df = df.drop(columns=['State Code'])
df
# Out:
#        Start Date    End Date     Group  Year  Month    state        Sex  \
# 0      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 1      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 2      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 3      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# 4      01/01/2020  09/23/2023  By Total     0      0  Alabama  All Sexes
# ...           ...         ...       ...   ...    ...      ...        ...
# 73435  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73436  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73437  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73438  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
# 73439  12/01/2022  12/31/2022  By Month  2022     12  Wyoming     Female
#
#                Age Group  COVID-19 Deaths  Total Deaths  ...  \
# 0               All Ages          21520.0      231602.0  ...
# 1           Under 1 year              NaN        1491.0  ...
# 2              1-4 years              NaN         344.0  ...
# 3             5-14 years              NaN         453.0  ...
# 4            15-24 years             46.0        2672.0  ...
# ...                  ...              ...           ...  ...
# 73435        45-54 years              0.0          11.0  ...
# 73436        55-64 years              NaN          25.0  ...
# 73437        65-74 years              NaN          35.0  ...
# 73438        75-84 years              NaN          48.0  ...
# 73439  85 years and over              NaN          83.0  ...
#
#        Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0                             7411.0             356.0
# 1                                NaN               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                               16.0               NaN
# ...                              ...               ...
# 73435                            0.0               0.0
# 73436                            NaN               0.0
# 73437                            NaN               NaN
# 73438                            NaN               NaN
# 73439                            0.0               0.0
#
#        Pneumonia, Influenza, or COVID-19 Deaths  Region estimate base  \
# 0                                       32038.0   South       5025369
# 1                                          24.0   South       5025369
# 2                                          19.0   South       5025369
# 3                                          16.0   South       5025369
# 4                                          85.0   South       5025369
# ...                                         ...     ...           ...
# 73435                                       NaN    West        576844
# 73436                                       NaN    West        576844
# 73437                                       NaN    West        576844
# 73438                                       NaN    West        576844
# 73439                                       NaN    West        576844
#
#        Population  land_area   density  death_density  covid_density
# 0             NaN   50645.33       NaN       4.573018       0.424916
# 1             NaN   50645.33       NaN       0.029440            NaN
# 2             NaN   50645.33       NaN       0.006792            NaN
# 3             NaN   50645.33       NaN       0.008945            NaN
# 4             NaN   50645.33       NaN       0.052759       0.000908
# ...           ...        ...       ...            ...            ...
# 73435    581978.0   97093.14  5.994018       0.000113       0.000000
# 73436    581978.0   97093.14  5.994018       0.000257            NaN
# 73437    581978.0   97093.14  5.994018       0.000360            NaN
# 73438    581978.0   97093.14  5.994018       0.000494            NaN
# 73439    581978.0   97093.14  5.994018       0.000855            NaN
#
# [73440 rows x 21 columns]

# %%
df['Group'].unique()
# Out:
# array(['By Total', 'By Year', 'By Month'], dtype=object)

# %% [markdown]
# # Find Correlation

# %%
df_allSex_allAges = df[(df['Sex'] == 'All Sexes') & (df['Age Group'] == 'All Ages') & (df['Group'] == 'By Year')]
df_allSex_allAges
# Out:
#       Start Date    End Date    Group  Year  Month      state        Sex  \
# 1836  01/01/2020  12/31/2020  By Year  2020      0    Alabama  All Sexes
# 1872  01/01/2021  12/31/2021  By Year  2021      0    Alabama  All Sexes
# 1908  01/01/2022  12/31/2022  By Year  2022      0    Alabama  All Sexes
# 1944  01/01/2020  12/31/2020  By Year  2020      0     Alaska  All Sexes
# 1980  01/01/2021  12/31/2021  By Year  2021      0     Alaska  All Sexes
# ...          ...         ...      ...   ...    ...        ...        ...
# 7164  01/01/2021  12/31/2021  By Year  2021      0  Wisconsin  All Sexes
# 7200  01/01/2022  12/31/2022  By Year  2022      0  Wisconsin  All Sexes
# 7236  01/01/2020  12/31/2020  By Year  2020      0    Wyoming  All Sexes
# 7272  01/01/2021  12/31/2021  By Year  2021      0    Wyoming  All Sexes
# 7308  01/01/2022  12/31/2022  By Year  2022      0    Wyoming  All Sexes
#
#      Age Group  COVID-19 Deaths  Total Deaths  ...  \
# 1836  All Ages           6706.0       63362.0  ...
# 1872  All Ages           9719.0       67323.0  ...
# 1908  All Ages           4226.0       61127.0  ...
# 1944  All Ages            254.0        5008.0  ...
# 1980  All Ages            839.0        6075.0  ...
# ...        ...              ...           ...  ...
# 7164  All Ages           6076.0       60807.0  ...
# 7200  All Ages           3912.0       60282.0  ...
# 7236  All Ages            461.0        5527.0  ...
# 7272  All Ages            963.0        5962.0  ...
# 7308  All Ages            353.0        5455.0  ...
#
#       Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 1836                         2177.0             140.0
# 1872                         3604.0              36.0
# 1908                         1349.0             132.0
# 1944                          142.0              10.0
# 1980                          502.0               NaN
# ...                             ...               ...
# 7164                         2472.0              13.0
# 7200                         1310.0             153.0
# 7236                          198.0              10.0
# 7272                          582.0               NaN
# 7308                          165.0              17.0
#
#       Pneumonia, Influenza, or COVID-19 Deaths   Region estimate base  \
# 1836                                    9870.0    South       5025369
# 1872                                   12496.0    South       5025369
# 1908                                    6931.0    South       5025369
# 1944                                     434.0     West        733395
# 1980                                    1005.0     West        733395
# ...                                        ...      ...           ...
# 7164                                    8287.0  Midwest       5894170
# 7200                                    6310.0  Midwest       5894170
# 7236                                     748.0     West        576844
# 7272                                    1191.0     West        576844
# 7308                                     585.0     West        576844
#
#       Population  land_area     density  death_density  covid_density
# 1836   5033094.0   50645.33   99.379232       1.251093       0.132411
# 1872   5049196.0   50645.33   99.697169       1.329303       0.191903
# 1908   5076181.0   50645.33  100.229992       1.206962       0.083443
# 1944    733017.0  570640.95    1.284550       0.008776       0.000445
# 1980    734420.0  570640.95    1.287009       0.010646       0.001470
# ...          ...        ...         ...            ...            ...
# 7164   5881608.0   54157.80  108.601310       1.122775       0.112191
# 7200   5903975.0   54157.80  109.014306       1.113081       0.072233
# 7236    577681.0   97093.14    5.949761       0.056925       0.004748
# 7272    579636.0   97093.14    5.969897       0.061405       0.009918
# 7308    581978.0   97093.14    5.994018       0.056183       0.003636
#
# [153 rows x 21 columns]

# %%
death_rate = (df_allSex_allAges.groupby(['state', 'Year','Age Group'],observed=False)['death_density'].sum() /
    df_allSex_allAges.groupby(['state', 'Year','Age Group'],observed=False)['density'].sum() 
) * 100

death_rate = death_rate.reset_index(name='Death Rate (%)')
print('Total Deaths')
print(death_rate)
# Out:
# Total Deaths
#          state  Year Age Group  Death Rate (%)
# 0      Alabama  2020  All Ages        1.258908
# 1      Alabama  2021  All Ages        1.333341
# 2      Alabama  2022  All Ages        1.204193
# 3       Alaska  2020  All Ages        0.683204
# 4       Alaska  2021  All Ages        0.827183
# ..         ...   ...       ...             ...
# 148  Wisconsin  2021  All Ages        1.033850
# 149  Wisconsin  2022  All Ages        1.021041
# 150    Wyoming  2020  All Ages        0.956756
# 151    Wyoming  2021  All Ages        1.028577
# 152    Wyoming  2022  All Ages        0.937321
#
# [153 rows x 4 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size and adjust the aspect ratio for larger plots
g = sns.FacetGrid(
    data=death_rate,
    col="Year",
    hue="Age Group",
    height=8,  # Increase height for larger plots
    aspect=2,  # Increase aspect ratio for wider plots
    palette="Set2"
)

# Create a bar plot for each year with separated bars for each Age Group
g.map(
    sns.barplot,
    "state",
    "Death Rate (%)",
    alpha=0.8,
    dodge=True,  # Separate the bars for each Age Group
    order=death_rate['state'].unique()
)

# Customize the plot
g.set_titles("Year: {col_name}")
g.set_axis_labels("State", "Death Rate (%)")
g.set_xticklabels(rotation=45, ha='right')
g.add_legend(title="Age Group")

# Adjust layout to prevent cutting off elements
plt.tight_layout()

# Show the plot
plt.show()

# %%
death_rate = (df_allSex_allAges.groupby(['state', 'Year','Age Group'],observed=False)['covid_density'].sum() /
    df_allSex_allAges.groupby(['state', 'Year','Age Group'],observed=False)['density'].sum() 
) * 100

death_rate = death_rate.reset_index(name='Death Rate (%)')
print('Total Deaths')
print(death_rate)
# Out:
# Total Deaths
#          state  Year Age Group  Death Rate (%)
# 0      Alabama  2020  All Ages        0.133238
# 1      Alabama  2021  All Ages        0.192486
# 2      Alabama  2022  All Ages        0.083252
# 3       Alaska  2020  All Ages        0.034651
# 4       Alaska  2021  All Ages        0.114240
# ..         ...   ...       ...             ...
# 148  Wisconsin  2021  All Ages        0.103305
# 149  Wisconsin  2022  All Ages        0.066260
# 150    Wyoming  2020  All Ages        0.079802
# 151    Wyoming  2021  All Ages        0.166139
# 152    Wyoming  2022  All Ages        0.060655
#
# [153 rows x 4 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size and adjust the aspect ratio for larger plots
g = sns.FacetGrid(
    data=death_rate,
    col="Year",
    hue="Age Group",
    height=8,  # Increase height for larger plots
    aspect=2,  # Increase aspect ratio for wider plots
    palette="Set2"
)

# Create a bar plot for each year with separated bars for each Age Group
g.map(
    sns.barplot,
    "state",
    "Death Rate (%)",
    alpha=0.8,
    dodge=True,  # Separate the bars for each Age Group
    order=death_rate['state'].unique()
)

# Customize the plot
g.set_titles("Year: {col_name}")
g.set_axis_labels("State", "Death Rate (%)")
g.set_xticklabels(rotation=45, ha='right')
g.add_legend(title="Age Group")

# Adjust layout to prevent cutting off elements
plt.tight_layout()

# Show the plot
plt.show()
